# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('gpa_iq.csv',sep=',',dtype={'placement':int})
df
# Out:
#     obs    gpa   iq  gender  placement
# 0     1  7.940  111       2          1
# 1     2  8.292  107       2          1
# 2     3  4.643  100       2          0
# 3     4  7.470  107       2          1
# 4     5  8.882  114       1          1
# ..  ...    ...  ...     ...        ...
# 73   85  9.000  112       1          1
# 74   86  9.500  112       1          1
# 75   87  6.057  114       2          1
# 76   88  6.057   93       1          1
# 77   89  6.938  106       2          1
#
# [78 rows x 5 columns]

# %%
df['placement'].dtype
# Out:
# dtype('int64')

# %%
import requests
from io import StringIO
url ="https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0(Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url,headers=headers)
data = StringIO(req.text)
pd.read_csv(data,names=['country','continent'],header=1)
# Out:
#        country      continent
# 0       Angola         AFRICA
# 1        Benin         AFRICA
# 2     Botswana         AFRICA
# 3      Burkina         AFRICA
# 4      Burundi         AFRICA
# ..         ...            ...
# 188   Paraguay  SOUTH AMERICA
# 189       Peru  SOUTH AMERICA
# 190   Suriname  SOUTH AMERICA
# 191    Uruguay  SOUTH AMERICA
# 192  Venezuela  SOUTH AMERICA
#
# [193 rows x 2 columns]

# %%
new_df = pd.read_csv('gpa_iq.csv',sep=',',usecols=['placement'],nrows=50) #error_bad_lines=False
new_df.head()
new_df.info
# Out:
# <bound method DataFrame.info of     placement
# 0           1
# 1           1
# 2           0
# 3           1
# 4           1
# 5           1
# 6           1
# 7           0
# 8           1
# 9           1
# 10          1
# 11          0
# 12          1
# 13          1
# 14          0
# 15          1
# 16          1
# 17          1
# 18          0
# 19          1
# 20          1
# 21          0
# 22          1
# 23          1
# 24          1
# 25          1
# 26          1
# 27          1
# 28          1
# 29          1
# 30          1
# 31          1
# 32          1
# 33          1
# 34          1
# 35          1
# 36          1
# 37          1
# 38          1
# 39          1
# 40          1
# 41          1
# 42          1
# 43          1
# 44          1
# 45          0
# 46          0
# 47          0
# 48          1
# 49          1>

# %%
dfs = pd.read_csv('gpa_iq.csv',chunksize=20)
for chunk in dfs:
    print(chunk.shape)
# Out:
# (20, 5)
# (20, 5)
# (20, 5)
# (18, 5)

# %%
def rename(name):
    if name=="Scotland":
        return "stockhome"
    else:
        return name

dataset = pd.read_csv('results.csv',parse_dates=['date'],converters={'home_team':rename})
# dataset.head().info
dataset
# Out:
#             date      home_team away_team  home_score  away_score  \
# 0     1872-11-30      stockhome   England           0           0
# 1     1873-03-08        England  Scotland           4           2
# 2     1874-03-07      stockhome   England           2           1
# 3     1875-03-06        England  Scotland           2           2
# 4     1876-03-04      stockhome   England           3           0
# ...          ...            ...       ...         ...         ...
# 44757 2023-07-09  United States    Canada           2           2
# 44758 2023-07-12  United States    Panama           1           1
# 44759 2023-07-12        Jamaica    Mexico           0           3
# 44760 2023-07-16         Kernow     Sápmi           2           1
# 44761 2023-07-16         Mexico    Panama           1           0
#
#                                     tournament        city        country  \
# 0                                     Friendly     Glasgow       Scotland
# ...
